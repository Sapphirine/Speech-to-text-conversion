# %%
import numpy as np
import librosa
import os
import time
import h5py

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
dir_path = 'all_data/AED_data'  # directory path

# load all event types
all_event = np.load(dir_path+'/event_types.npy')
print(all_event)
# Out:
# ['beach' 'bus' 'cafe/restaurant' 'car' 'city_center' 'forest_path'
#  'grocery_store' 'home' 'library' 'metro_station' 'office' 'park'
#  'residential_area' 'train' 'tram']

# %%
train_label = np.load(dir_path+'/train_labels.npy')
print(train_label[0])  # (label, audio_file) pair
# Out:
# ['beach' 'b019_170_180.wav']

# %%
# walk through the directory, find the files with .wav extension
# Initialize an empty list to store the filenames of .wav files found in the directory
wav_files = []

# Walk through the directory and collect filenames of files with .wav extension
for (dirpath, dirnames, filenames) in os.walk(dir_path):
    for file in filenames:
        if '.wav' in file:  # Check if the file has a .wav extension
            wav_files.append(file)  # Append the filename to the list

# Calculate the total number of .wav files found
num_data = len(wav_files)

# Load validation and test labels from saved numpy files
val_label = np.load(dir_path+'/validation_labels.npy')
test_label = np.load(dir_path+'/test_labels.npy')

# Initialize empty lists to store audio data and target labels for training, validation, and testing
train_audio = []
val_audio = []
test_audio = []
train_target = []
val_target = []
test_target = []

# Load and preprocess audio data and target labels for training
for i in range(len(train_label)):
    # Load audio file and convert it to 10 seconds duration (16000 samples per second)
    y, _ = librosa.load(dir_path+'/audio/'+train_label[i][1], sr=16000)
    train_audio.append(y[:16000*10])
    # Map the target label to its corresponding index in the list of all events
    train_target.append(np.argmax((train_label[i][0] == np.array(all_event)).astype(np.float32)))

# Load and preprocess audio data and target labels for validation
for i in range(len(val_label)):
    y, _ = librosa.load(dir_path+'/audio/'+val_label[i][1], sr=16000)
    val_audio.append(y[:16000*10]) 
    val_target.append(np.argmax((val_label[i][0] == np.array(all_event)).astype(np.float32)))

# Load and preprocess audio data and target labels for testing
for i in range(len(test_label)):
    y, _ = librosa.load(dir_path+'/audio/'+test_label[i][1], sr=16000)
    test_audio.append(y[:16000*10])
    test_target.append(np.argmax((test_label[i][0] == np.array(all_event)).astype(np.float32)))

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=15):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=11, stride=4, padding=2),  # number of input channel is 1
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(16, 32, kernel_size=5, padding=2), 
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((3, 3))  # perform adaptive mean pooling on any size of the input to match the provided size
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(64 * 3 * 3, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(256, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        # Forward pass through the network
        x = self.features(x)
        x = self.avgpool(x)  # the dimension after adaptive average pooling is (batch, 64, 3, 3)
        x = torch.flatten(x, 1)  # average
        x = self.classifier(x)
        return x
    
# test it with a sample input
model = AlexNet()
sample_input = torch.randn(2, 1, 257, 626)  # (batch_size, num_channel, freq_dim, time_step)
# Forward pass through the model
sample_output = model(sample_input)
print(sample_output.shape)  # (batch_size, num_classes)
# Out:
# torch.Size([2, 15])

# %%
from torch.utils.data import Dataset, DataLoader

batch_size = 8

# Custom dataset class for data processing
class dataset_pipeline(Dataset):
    def __init__(self, data, label):
        super(dataset_pipeline, self).__init__()
        self.data = data
        self.label = label
        self._len = len(self.data)  # Number of utterances

    def __getitem__(self, index):
        # Calculate STFT here
        spec = librosa.stft(self.data[index].astype(np.float32), n_fft=512, hop_length=256)
        label = self.label[index]
        spec = torch.from_numpy(np.abs(spec))  # Use only the magnitude spectrogram
        label = torch.from_numpy(np.array(label)).long()
        return spec, label

    def __len__(self):
        return self._len

# Define data loaders
train_loader = DataLoader(dataset_pipeline(train_audio, train_target), 
                          batch_size=batch_size, 
                          shuffle=True,
                         )

validation_loader = DataLoader(dataset_pipeline(val_audio, val_target), 
                               batch_size=batch_size, 
                               shuffle=False,
                              )

# Define cross-entropy loss function
def CE(output, target):
    loss = nn.CrossEntropyLoss()
    return loss(output, target)

# Training function
def train(model, epoch):
    start_time = time.time()
    model = model.train()  # Set the model to training mode
    train_loss = 0.

    for batch_idx, data in enumerate(train_loader):
        spec, label = data
        optimizer.zero_grad()
        output = model(spec.unsqueeze(1))
        loss = CE(output, label)
        loss.backward()
        optimizer.step()
        train_loss += loss.data.item()

        # Print training progress
        if (batch_idx+1) % log_step == 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | ms/batch {:5.2f} | CE {:5.4f} |'.format(
                epoch, batch_idx+1, len(train_loader),
                elapsed * 1000 / (batch_idx+1), 
                train_loss / (batch_idx+1)
            ))

    train_loss /= (batch_idx+1)
    print('-' * 99)
    print('    | end of training epoch {:3d} | time: {:5.2f}s | CE {:5.4f} |'.format(
        epoch, (time.time() - start_time), train_loss))
    return train_loss

# Validation function
def validate(model, epoch):
    start_time = time.time()
    model = model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0

    for batch_idx, data in enumerate(validation_loader):
        spec, label = data
        with torch.no_grad():  # Perform forward pass only during validation
            output = model(spec.unsqueeze(1))
            _, output_label = torch.max(output, 1)
            output_label = output_label.data.numpy()
            label = label.data.numpy()
            correct += np.sum(output_label == label)
            total += len(label)

    accuracy = correct / total
    print('    | end of validation epoch {:3d} | time: {:5.2f}s | Accuracy {:5.4f} |'.format(
        epoch, (time.time() - start_time), accuracy))
    print('-' * 99)
    return accuracy

total_epoch = 100  # Train for 100 epochs
model_save = 'best_AlexNet.pt'  # Path to save the best validation model
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Main training loop
training_loss = []
validation_loss = []

for epoch in range(1, total_epoch + 1):
    training_loss.append(train(model, epoch))
    validation_loss.append(validate(model, epoch))

    if training_loss[-1] == np.min(training_loss):
        print('      Best training model found.')
    if validation_loss[-1] == np.max(validation_loss):
        # Save current best model on validation set
        with open(model_save, 'wb') as f:
            torch.save(model.state_dict(), f)
            print('      Best validation model found and saved.')

    print('-' * 99)
# Out:
# | epoch   1 |    12/   51 batches | ms/batch 76.05 | CE 2.7156 |
# | epoch   1 |    24/   51 batches | ms/batch 73.59 | CE 2.7059 |
# | epoch   1 |    36/   51 batches | ms/batch 73.77 | CE 2.6873 |
# | epoch   1 |    48/   51 batches | ms/batch 72.37 | CE 2.6629 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   1 | time:  3.66s | CE 2.6518 |
#     | end of validation epoch   1 | time:  0.11s | Accuracy 0.1333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch   2 |    12/   51 batches | ms/batch 70.14 | CE 2.5094 |
# | epoch   2 |    24/   51 batches | ms/batch 63.65 | CE 2.5193 |
# | epoch   2 |    36/   51 batches | ms/batch 64.39 | CE 2.5166 |
# | epoch   2 |    48/   51 batches | ms/batch 64.16 | CE 2.4941 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   2 | time:  3.25s | CE 2.4767 |
#     | end of validation epoch   2 | time:  0.11s | Accuracy 0.1333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch   3 |    12/   51 batches | ms/batch 70.56 | CE 2.2565 |
# | epoch   3 |    24/   51 batches | ms/batch 65.88 | CE 2.2822 |
# | epoch   3 |    36/   51 batches | ms/batch 65.09 | CE 2.2859 |
# | epoch   3 |    48/   51 batches | ms/batch 64.45 | CE 2.3035 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   3 | time:  3.26s | CE 2.3132 |
#     | end of validation epoch   3 | time:  0.10s | Accuracy 0.2000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch   4 |    12/   51 batches | ms/batch 68.40 | CE 2.2856 |
# | epoch   4 |    24/   51 batches | ms/batch 66.73 | CE 2.3085 |
# | epoch   4 |    36/   51 batches | ms/batch 64.01 | CE 2.2767 |
# | epoch   4 |    48/   51 batches | ms/batch 64.83 | CE 2.2418 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   4 | time:  3.29s | CE 2.2352 |
#     | end of validation epoch   4 | time:  0.10s | Accuracy 0.1667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch   5 |    12/   51 batches | ms/batch 66.04 | CE 2.2819 |
# | epoch   5 |    24/   51 batches | ms/batch 64.27 | CE 2.2493 |
# | epoch   5 |    36/   51 batches | ms/batch 62.11 | CE 2.2206 |
# | epoch   5 |    48/   51 batches | ms/batch 62.92 | CE 2.1849 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   5 | time:  3.19s | CE 2.1822 |
#     | end of validation epoch   5 | time:  0.10s | Accuracy 0.2000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch   6 |    12/   51 batches | ms/batch 57.68 | CE 2.1529 |
# | epoch   6 |    24/   51 batches | ms/batch 61.11 | CE 2.1511 |
# | epoch   6 |    36/   51 batches | ms/batch 59.90 | CE 2.0957 |
# | epoch   6 |    48/   51 batches | ms/batch 60.63 | CE 2.1283 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   6 | time:  3.09s | CE 2.1098 |
#     | end of validation epoch   6 | time:  0.10s | Accuracy 0.2667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch   7 |    12/   51 batches | ms/batch 59.85 | CE 2.1348 |
# | epoch   7 |    24/   51 batches | ms/batch 61.28 | CE 2.0796 |
# | epoch   7 |    36/   51 batches | ms/batch 59.81 | CE 2.0478 |
# | epoch   7 |    48/   51 batches | ms/batch 60.10 | CE 2.0509 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   7 | time:  3.07s | CE 2.0513 |
#     | end of validation epoch   7 | time:  0.10s | Accuracy 0.1667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch   8 |    12/   51 batches | ms/batch 57.97 | CE 2.0553 |
# | epoch   8 |    24/   51 batches | ms/batch 60.95 | CE 2.0679 |
# | epoch   8 |    36/   51 batches | ms/batch 63.64 | CE 2.0101 |
# | epoch   8 |    48/   51 batches | ms/batch 63.63 | CE 2.0389 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   8 | time:  3.27s | CE 2.0601 |
#     | end of validation epoch   8 | time:  0.12s | Accuracy 0.2000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch   9 |    12/   51 batches | ms/batch 62.43 | CE 1.8512 |
# | epoch   9 |    24/   51 batches | ms/batch 64.70 | CE 1.9103 |
# | epoch   9 |    36/   51 batches | ms/batch 63.99 | CE 1.9164 |
# | epoch   9 |    48/   51 batches | ms/batch 62.87 | CE 1.9223 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch   9 | time:  3.22s | CE 1.9224 |
#     | end of validation epoch   9 | time:  0.11s | Accuracy 0.3000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  10 |    12/   51 batches | ms/batch 65.26 | CE 1.8293 |
# | epoch  10 |    24/   51 batches | ms/batch 65.59 | CE 1.9041 |
# | epoch  10 |    36/   51 batches | ms/batch 68.62 | CE 1.8953 |
# | epoch  10 |    48/   51 batches | ms/batch 66.84 | CE 1.8858 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  10 | time:  3.42s | CE 1.8851 |
#     | end of validation epoch  10 | time:  0.12s | Accuracy 0.3000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  11 |    12/   51 batches | ms/batch 66.12 | CE 1.8656 |
# | epoch  11 |    24/   51 batches | ms/batch 63.57 | CE 1.8863 |
# | epoch  11 |    36/   51 batches | ms/batch 64.61 | CE 1.8673 |
# | epoch  11 |    48/   51 batches | ms/batch 63.32 | CE 1.8815 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  11 | time:  3.23s | CE 1.8683 |
#     | end of validation epoch  11 | time:  0.12s | Accuracy 0.4000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  12 |    12/   51 batches | ms/batch 63.70 | CE 1.6882 |
# | epoch  12 |    24/   51 batches | ms/batch 62.07 | CE 1.7026 |
# | epoch  12 |    36/   51 batches | ms/batch 64.24 | CE 1.6898 |
# | epoch  12 |    48/   51 batches | ms/batch 63.65 | CE 1.7747 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  12 | time:  3.24s | CE 1.7931 |
#     | end of validation epoch  12 | time:  0.12s | Accuracy 0.3667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  13 |    12/   51 batches | ms/batch 70.77 | CE 1.7574 |
# | epoch  13 |    24/   51 batches | ms/batch 64.57 | CE 1.7782 |
# | epoch  13 |    36/   51 batches | ms/batch 65.49 | CE 1.7940 |
# | epoch  13 |    48/   51 batches | ms/batch 63.65 | CE 1.8063 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  13 | time:  3.22s | CE 1.8048 |
#     | end of validation epoch  13 | time:  0.10s | Accuracy 0.3333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  14 |    12/   51 batches | ms/batch 63.03 | CE 1.8442 |
# | epoch  14 |    24/   51 batches | ms/batch 60.34 | CE 1.8456 |
# | epoch  14 |    36/   51 batches | ms/batch 61.43 | CE 1.8260 |
# | epoch  14 |    48/   51 batches | ms/batch 60.83 | CE 1.8371 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  14 | time:  3.09s | CE 1.8392 |
#     | end of validation epoch  14 | time:  0.10s | Accuracy 0.4333 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  15 |    12/   51 batches | ms/batch 62.70 | CE 1.6645 |
# | epoch  15 |    24/   51 batches | ms/batch 61.81 | CE 1.6716 |
# | epoch  15 |    36/   51 batches | ms/batch 64.84 | CE 1.6833 |
# | epoch  15 |    48/   51 batches | ms/batch 65.33 | CE 1.7160 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  15 | time:  3.32s | CE 1.7123 |
#     | end of validation epoch  15 | time:  0.10s | Accuracy 0.3667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  16 |    12/   51 batches | ms/batch 62.98 | CE 1.6434 |
# | epoch  16 |    24/   51 batches | ms/batch 60.62 | CE 1.7302 |
# | epoch  16 |    36/   51 batches | ms/batch 61.23 | CE 1.7399 |
# | epoch  16 |    48/   51 batches | ms/batch 61.00 | CE 1.7238 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  16 | time:  3.11s | CE 1.7235 |
#     | end of validation epoch  16 | time:  0.11s | Accuracy 0.3333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  17 |    12/   51 batches | ms/batch 63.32 | CE 1.7558 |
# | epoch  17 |    24/   51 batches | ms/batch 61.87 | CE 1.6892 |
# | epoch  17 |    36/   51 batches | ms/batch 61.74 | CE 1.6819 |
# | epoch  17 |    48/   51 batches | ms/batch 61.37 | CE 1.6928 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  17 | time:  3.12s | CE 1.6953 |
#     | end of validation epoch  17 | time:  0.11s | Accuracy 0.4000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  18 |    12/   51 batches | ms/batch 64.77 | CE 1.5949 |
# | epoch  18 |    24/   51 batches | ms/batch 64.51 | CE 1.6086 |
# | epoch  18 |    36/   51 batches | ms/batch 63.14 | CE 1.6299 |
# | epoch  18 |    48/   51 batches | ms/batch 62.56 | CE 1.6307 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  18 | time:  3.18s | CE 1.6335 |
#     | end of validation epoch  18 | time:  0.10s | Accuracy 0.4000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  19 |    12/   51 batches | ms/batch 61.99 | CE 1.6490 |
# | epoch  19 |    24/   51 batches | ms/batch 61.32 | CE 1.6189 |
# | epoch  19 |    36/   51 batches | ms/batch 61.19 | CE 1.5896 |
# | epoch  19 |    48/   51 batches | ms/batch 62.06 | CE 1.5753 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  19 | time:  3.16s | CE 1.5816 |
#     | end of validation epoch  19 | time:  0.10s | Accuracy 0.3000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  20 |    12/   51 batches | ms/batch 64.36 | CE 1.4856 |
# | epoch  20 |    24/   51 batches | ms/batch 63.50 | CE 1.4914 |
# | epoch  20 |    36/   51 batches | ms/batch 64.23 | CE 1.5408 |
# | epoch  20 |    48/   51 batches | ms/batch 65.18 | CE 1.5174 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  20 | time:  3.32s | CE 1.5246 |
#     | end of validation epoch  20 | time:  0.10s | Accuracy 0.5333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  21 |    12/   51 batches | ms/batch 68.69 | CE 1.6391 |
# | epoch  21 |    24/   51 batches | ms/batch 67.26 | CE 1.5196 |
# | epoch  21 |    36/   51 batches | ms/batch 66.83 | CE 1.5796 |
# | epoch  21 |    48/   51 batches | ms/batch 66.36 | CE 1.5839 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  21 | time:  3.37s | CE 1.6100 |
#     | end of validation epoch  21 | time:  0.11s | Accuracy 0.4333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  22 |    12/   51 batches | ms/batch 72.58 | CE 1.5173 |
# | epoch  22 |    24/   51 batches | ms/batch 84.11 | CE 1.5855 |
# | epoch  22 |    36/   51 batches | ms/batch 87.98 | CE 1.5213 |
# | epoch  22 |    48/   51 batches | ms/batch 87.62 | CE 1.4752 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  22 | time:  4.51s | CE 1.5217 |
#     | end of validation epoch  22 | time:  0.21s | Accuracy 0.5000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  23 |    12/   51 batches | ms/batch 82.09 | CE 1.6362 |
# | epoch  23 |    24/   51 batches | ms/batch 92.48 | CE 1.5608 |
# | epoch  23 |    36/   51 batches | ms/batch 94.87 | CE 1.4916 |
# | epoch  23 |    48/   51 batches | ms/batch 94.06 | CE 1.4763 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  23 | time:  4.76s | CE 1.4739 |
#     | end of validation epoch  23 | time:  0.13s | Accuracy 0.4667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  24 |    12/   51 batches | ms/batch 82.84 | CE 1.3516 |
# | epoch  24 |    24/   51 batches | ms/batch 88.29 | CE 1.3848 |
# | epoch  24 |    36/   51 batches | ms/batch 140.39 | CE 1.4139 |
# | epoch  24 |    48/   51 batches | ms/batch 168.90 | CE 1.4096 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  24 | time:  8.89s | CE 1.4099 |
#     | end of validation epoch  24 | time:  0.34s | Accuracy 0.5667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  25 |    12/   51 batches | ms/batch 249.18 | CE 1.3606 |
# | epoch  25 |    24/   51 batches | ms/batch 252.29 | CE 1.3270 |
# | epoch  25 |    36/   51 batches | ms/batch 265.02 | CE 1.4040 |
# | epoch  25 |    48/   51 batches | ms/batch 260.15 | CE 1.4109 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  25 | time: 13.19s | CE 1.4159 |
#     | end of validation epoch  25 | time:  0.41s | Accuracy 0.4000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  26 |    12/   51 batches | ms/batch 271.56 | CE 1.2695 |
# | epoch  26 |    24/   51 batches | ms/batch 282.55 | CE 1.3486 |
# | epoch  26 |    36/   51 batches | ms/batch 286.76 | CE 1.4017 |
# | epoch  26 |    48/   51 batches | ms/batch 235.75 | CE 1.3460 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  26 | time: 11.57s | CE 1.3512 |
#     | end of validation epoch  26 | time:  0.15s | Accuracy 0.5000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  27 |    12/   51 batches | ms/batch 80.50 | CE 1.1745 |
# | epoch  27 |    24/   51 batches | ms/batch 81.91 | CE 1.2746 |
# | epoch  27 |    36/   51 batches | ms/batch 81.34 | CE 1.3271 |
# | epoch  27 |    48/   51 batches | ms/batch 80.34 | CE 1.2792 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  27 | time:  4.12s | CE 1.3127 |
#     | end of validation epoch  27 | time:  0.15s | Accuracy 0.4333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  28 |    12/   51 batches | ms/batch 96.04 | CE 1.3832 |
# | epoch  28 |    24/   51 batches | ms/batch 87.68 | CE 1.4135 |
# | epoch  28 |    36/   51 batches | ms/batch 85.12 | CE 1.4028 |
# | epoch  28 |    48/   51 batches | ms/batch 82.72 | CE 1.3304 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  28 | time:  4.20s | CE 1.3334 |
#     | end of validation epoch  28 | time:  0.13s | Accuracy 0.5000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  29 |    12/   51 batches | ms/batch 90.94 | CE 1.3326 |
# | epoch  29 |    24/   51 batches | ms/batch 90.24 | CE 1.3374 |
# | epoch  29 |    36/   51 batches | ms/batch 90.36 | CE 1.3385 |
# | epoch  29 |    48/   51 batches | ms/batch 91.12 | CE 1.2655 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  29 | time:  4.67s | CE 1.2617 |
#     | end of validation epoch  29 | time:  0.16s | Accuracy 0.5333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  30 |    12/   51 batches | ms/batch 98.28 | CE 1.1721 |
# | epoch  30 |    24/   51 batches | ms/batch 179.64 | CE 1.1043 |
# | epoch  30 |    36/   51 batches | ms/batch 199.91 | CE 1.1541 |
# | epoch  30 |    48/   51 batches | ms/batch 215.64 | CE 1.2029 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  30 | time: 11.13s | CE 1.2160 |
#     | end of validation epoch  30 | time:  0.42s | Accuracy 0.5333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  31 |    12/   51 batches | ms/batch 251.80 | CE 1.0347 |
# | epoch  31 |    24/   51 batches | ms/batch 254.84 | CE 1.0133 |
# | epoch  31 |    36/   51 batches | ms/batch 247.48 | CE 1.0998 |
# | epoch  31 |    48/   51 batches | ms/batch 251.49 | CE 1.1273 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  31 | time: 12.91s | CE 1.1127 |
#     | end of validation epoch  31 | time:  0.39s | Accuracy 0.4333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  32 |    12/   51 batches | ms/batch 256.93 | CE 1.1385 |
# | epoch  32 |    24/   51 batches | ms/batch 256.93 | CE 1.2933 |
# | epoch  32 |    36/   51 batches | ms/batch 250.96 | CE 1.2892 |
# | epoch  32 |    48/   51 batches | ms/batch 257.61 | CE 1.2833 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  32 | time: 13.19s | CE 1.2943 |
#     | end of validation epoch  32 | time:  0.42s | Accuracy 0.6000 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  33 |    12/   51 batches | ms/batch 266.90 | CE 1.5276 |
# | epoch  33 |    24/   51 batches | ms/batch 260.42 | CE 1.3174 |
# | epoch  33 |    36/   51 batches | ms/batch 260.44 | CE 1.2576 |
# | epoch  33 |    48/   51 batches | ms/batch 258.95 | CE 1.2428 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  33 | time: 13.15s | CE 1.2223 |
#     | end of validation epoch  33 | time:  0.38s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  34 |    12/   51 batches | ms/batch 242.88 | CE 1.1179 |
# | epoch  34 |    24/   51 batches | ms/batch 252.07 | CE 1.0480 |
# | epoch  34 |    36/   51 batches | ms/batch 245.63 | CE 1.0504 |
# | epoch  34 |    48/   51 batches | ms/batch 250.04 | CE 1.0861 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  34 | time: 12.78s | CE 1.0840 |
#     | end of validation epoch  34 | time:  0.38s | Accuracy 0.6000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  35 |    12/   51 batches | ms/batch 257.63 | CE 1.0673 |
# | epoch  35 |    24/   51 batches | ms/batch 255.56 | CE 1.1701 |
# | epoch  35 |    36/   51 batches | ms/batch 241.77 | CE 1.1087 |
# | epoch  35 |    48/   51 batches | ms/batch 246.72 | CE 1.1316 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  35 | time: 12.55s | CE 1.1315 |
#     | end of validation epoch  35 | time:  0.40s | Accuracy 0.5667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  36 |    12/   51 batches | ms/batch 247.36 | CE 0.9890 |
# | epoch  36 |    24/   51 batches | ms/batch 251.20 | CE 0.9350 |
# | epoch  36 |    36/   51 batches | ms/batch 257.15 | CE 1.0625 |
# | epoch  36 |    48/   51 batches | ms/batch 254.65 | CE 1.0324 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  36 | time: 13.26s | CE 1.0378 |
#     | end of validation epoch  36 | time:  0.43s | Accuracy 0.5333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  37 |    12/   51 batches | ms/batch 217.36 | CE 0.7863 |
# | epoch  37 |    24/   51 batches | ms/batch 149.76 | CE 0.9516 |
# | epoch  37 |    36/   51 batches | ms/batch 125.76 | CE 0.9875 |
# | epoch  37 |    48/   51 batches | ms/batch 114.82 | CE 1.0548 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  37 | time:  5.72s | CE 1.0482 |
#     | end of validation epoch  37 | time:  0.13s | Accuracy 0.5333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  38 |    12/   51 batches | ms/batch 85.56 | CE 0.8202 |
# | epoch  38 |    24/   51 batches | ms/batch 81.40 | CE 0.8314 |
# | epoch  38 |    36/   51 batches | ms/batch 82.52 | CE 0.8437 |
# | epoch  38 |    48/   51 batches | ms/batch 81.56 | CE 0.8798 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  38 | time:  4.15s | CE 0.8671 |
#     | end of validation epoch  38 | time:  0.14s | Accuracy 0.5667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  39 |    12/   51 batches | ms/batch 84.91 | CE 1.0300 |
# | epoch  39 |    24/   51 batches | ms/batch 80.88 | CE 0.9499 |
# | epoch  39 |    36/   51 batches | ms/batch 81.39 | CE 0.9683 |
# | epoch  39 |    48/   51 batches | ms/batch 79.28 | CE 0.9877 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  39 | time:  4.07s | CE 0.9744 |
#     | end of validation epoch  39 | time:  0.14s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  40 |    12/   51 batches | ms/batch 78.90 | CE 0.7805 |
# | epoch  40 |    24/   51 batches | ms/batch 82.54 | CE 0.7287 |
# | epoch  40 |    36/   51 batches | ms/batch 82.28 | CE 0.8464 |
# | epoch  40 |    48/   51 batches | ms/batch 82.43 | CE 0.8289 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  40 | time:  4.17s | CE 0.8255 |
#     | end of validation epoch  40 | time:  0.14s | Accuracy 0.5667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  41 |    12/   51 batches | ms/batch 78.56 | CE 0.7601 |
# | epoch  41 |    24/   51 batches | ms/batch 79.58 | CE 0.8064 |
# | epoch  41 |    36/   51 batches | ms/batch 80.10 | CE 0.8806 |
# | epoch  41 |    48/   51 batches | ms/batch 81.80 | CE 0.8586 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  41 | time:  4.14s | CE 0.8410 |
#     | end of validation epoch  41 | time:  0.12s | Accuracy 0.5667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  42 |    12/   51 batches | ms/batch 94.41 | CE 0.7082 |
# | epoch  42 |    24/   51 batches | ms/batch 91.88 | CE 0.8204 |
# | epoch  42 |    36/   51 batches | ms/batch 91.45 | CE 0.8393 |
# | epoch  42 |    48/   51 batches | ms/batch 89.85 | CE 0.8519 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  42 | time:  4.60s | CE 0.8622 |
#     | end of validation epoch  42 | time:  0.15s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  43 |    12/   51 batches | ms/batch 80.83 | CE 0.8814 |
# | epoch  43 |    24/   51 batches | ms/batch 83.33 | CE 0.8341 |
# | epoch  43 |    36/   51 batches | ms/batch 86.13 | CE 0.9029 |
# | epoch  43 |    48/   51 batches | ms/batch 91.28 | CE 0.9927 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  43 | time:  5.19s | CE 0.9737 |
#     | end of validation epoch  43 | time:  0.34s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  44 |    12/   51 batches | ms/batch 210.43 | CE 0.9362 |
# | epoch  44 |    24/   51 batches | ms/batch 223.52 | CE 0.9414 |
# | epoch  44 |    36/   51 batches | ms/batch 237.25 | CE 0.8998 |
# | epoch  44 |    48/   51 batches | ms/batch 243.41 | CE 0.9136 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  44 | time: 12.49s | CE 0.8955 |
#     | end of validation epoch  44 | time:  0.39s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  45 |    12/   51 batches | ms/batch 239.64 | CE 0.8319 |
# | epoch  45 |    24/   51 batches | ms/batch 257.46 | CE 0.8216 |
# | epoch  45 |    36/   51 batches | ms/batch 266.11 | CE 0.7466 |
# | epoch  45 |    48/   51 batches | ms/batch 266.84 | CE 0.7140 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  45 | time: 13.63s | CE 0.7310 |
#     | end of validation epoch  45 | time:  0.35s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  46 |    12/   51 batches | ms/batch 234.41 | CE 0.5892 |
# | epoch  46 |    24/   51 batches | ms/batch 243.06 | CE 0.6554 |
# | epoch  46 |    36/   51 batches | ms/batch 252.92 | CE 0.6190 |
# | epoch  46 |    48/   51 batches | ms/batch 255.34 | CE 0.6573 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  46 | time: 13.04s | CE 0.6907 |
#     | end of validation epoch  46 | time:  0.32s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  47 |    12/   51 batches | ms/batch 233.63 | CE 0.7540 |
# | epoch  47 |    24/   51 batches | ms/batch 252.65 | CE 0.6820 |
# | epoch  47 |    36/   51 batches | ms/batch 254.47 | CE 0.7111 |
# | epoch  47 |    48/   51 batches | ms/batch 255.88 | CE 0.7093 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  47 | time: 13.00s | CE 0.7217 |
#     | end of validation epoch  47 | time:  0.39s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  48 |    12/   51 batches | ms/batch 239.90 | CE 0.7197 |
# | epoch  48 |    24/   51 batches | ms/batch 253.48 | CE 0.7215 |
# | epoch  48 |    36/   51 batches | ms/batch 255.91 | CE 0.6785 |
# | epoch  48 |    48/   51 batches | ms/batch 251.06 | CE 0.6859 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  48 | time: 12.80s | CE 0.7191 |
#     | end of validation epoch  48 | time:  0.33s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  49 |    12/   51 batches | ms/batch 227.33 | CE 0.6854 |
# | epoch  49 |    24/   51 batches | ms/batch 235.70 | CE 0.6134 |
# | epoch  49 |    36/   51 batches | ms/batch 249.16 | CE 0.5904 |
# | epoch  49 |    48/   51 batches | ms/batch 254.83 | CE 0.6040 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  49 | time: 13.00s | CE 0.6034 |
#     | end of validation epoch  49 | time:  0.37s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  50 |    12/   51 batches | ms/batch 255.74 | CE 0.6664 |
# | epoch  50 |    24/   51 batches | ms/batch 522.23 | CE 0.5546 |
# | epoch  50 |    36/   51 batches | ms/batch 428.34 | CE 0.5708 |
# | epoch  50 |    48/   51 batches | ms/batch 379.45 | CE 0.6328 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  50 | time: 18.94s | CE 0.6786 |
#     | end of validation epoch  50 | time:  0.37s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  51 |    12/   51 batches | ms/batch 240.33 | CE 0.7957 |
# | epoch  51 |    24/   51 batches | ms/batch 261.09 | CE 0.7307 |
# | epoch  51 |    36/   51 batches | ms/batch 257.87 | CE 0.7077 |
# | epoch  51 |    48/   51 batches | ms/batch 257.03 | CE 0.7334 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  51 | time: 13.21s | CE 0.7267 |
#     | end of validation epoch  51 | time:  0.38s | Accuracy 0.6000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  52 |    12/   51 batches | ms/batch 250.94 | CE 0.8792 |
# | epoch  52 |    24/   51 batches | ms/batch 259.05 | CE 0.7559 |
# | epoch  52 |    36/   51 batches | ms/batch 252.58 | CE 0.7526 |
# | epoch  52 |    48/   51 batches | ms/batch 249.76 | CE 0.7199 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  52 | time: 12.75s | CE 0.7172 |
#     | end of validation epoch  52 | time:  0.37s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  53 |    12/   51 batches | ms/batch 274.18 | CE 0.6073 |
# | epoch  53 |    24/   51 batches | ms/batch 267.83 | CE 0.5585 |
# | epoch  53 |    36/   51 batches | ms/batch 272.89 | CE 0.5442 |
# | epoch  53 |    48/   51 batches | ms/batch 266.47 | CE 0.5907 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  53 | time: 13.52s | CE 0.5839 |
#     | end of validation epoch  53 | time:  0.42s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  54 |    12/   51 batches | ms/batch 260.78 | CE 0.6654 |
# | epoch  54 |    24/   51 batches | ms/batch 258.37 | CE 0.6098 |
# | epoch  54 |    36/   51 batches | ms/batch 260.41 | CE 0.5647 |
# | epoch  54 |    48/   51 batches | ms/batch 259.12 | CE 0.5593 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  54 | time: 12.72s | CE 0.5625 |
#     | end of validation epoch  54 | time:  0.12s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  55 |    12/   51 batches | ms/batch 73.13 | CE 0.5096 |
# | epoch  55 |    24/   51 batches | ms/batch 76.79 | CE 0.4943 |
# | epoch  55 |    36/   51 batches | ms/batch 75.57 | CE 0.5391 |
# | epoch  55 |    48/   51 batches | ms/batch 76.33 | CE 0.5265 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  55 | time:  3.89s | CE 0.5368 |
#     | end of validation epoch  55 | time:  0.12s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  56 |    12/   51 batches | ms/batch 84.35 | CE 0.4748 |
# | epoch  56 |    24/   51 batches | ms/batch 81.79 | CE 0.6006 |
# | epoch  56 |    36/   51 batches | ms/batch 81.60 | CE 0.5953 |
# | epoch  56 |    48/   51 batches | ms/batch 79.49 | CE 0.5955 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  56 | time:  4.01s | CE 0.6141 |
#     | end of validation epoch  56 | time:  0.13s | Accuracy 0.7667 |
# ---------------------------------------------------------------------------------------------------
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  57 |    12/   51 batches | ms/batch 89.14 | CE 0.5676 |
# | epoch  57 |    24/   51 batches | ms/batch 83.22 | CE 0.5368 |
# | epoch  57 |    36/   51 batches | ms/batch 85.27 | CE 0.5864 |
# | epoch  57 |    48/   51 batches | ms/batch 82.18 | CE 0.5565 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  57 | time:  4.18s | CE 0.5989 |
#     | end of validation epoch  57 | time:  0.14s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  58 |    12/   51 batches | ms/batch 82.16 | CE 0.8588 |
# | epoch  58 |    24/   51 batches | ms/batch 80.33 | CE 0.9624 |
# | epoch  58 |    36/   51 batches | ms/batch 80.44 | CE 0.8206 |
# | epoch  58 |    48/   51 batches | ms/batch 80.29 | CE 0.8457 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  58 | time:  4.11s | CE 0.8410 |
#     | end of validation epoch  58 | time:  0.14s | Accuracy 0.5667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  59 |    12/   51 batches | ms/batch 77.71 | CE 0.5764 |
# | epoch  59 |    24/   51 batches | ms/batch 82.41 | CE 0.6071 |
# | epoch  59 |    36/   51 batches | ms/batch 80.59 | CE 0.5878 |
# | epoch  59 |    48/   51 batches | ms/batch 82.36 | CE 0.5804 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  59 | time:  4.23s | CE 0.5870 |
#     | end of validation epoch  59 | time:  0.15s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  60 |    12/   51 batches | ms/batch 78.82 | CE 0.5440 |
# | epoch  60 |    24/   51 batches | ms/batch 83.12 | CE 0.5236 |
# | epoch  60 |    36/   51 batches | ms/batch 81.34 | CE 0.5490 |
# | epoch  60 |    48/   51 batches | ms/batch 82.40 | CE 0.5081 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  60 | time:  4.16s | CE 0.5135 |
#     | end of validation epoch  60 | time:  0.13s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  61 |    12/   51 batches | ms/batch 78.92 | CE 0.4728 |
# | epoch  61 |    24/   51 batches | ms/batch 77.93 | CE 0.5188 |
# | epoch  61 |    36/   51 batches | ms/batch 78.51 | CE 0.5274 |
# | epoch  61 |    48/   51 batches | ms/batch 78.15 | CE 0.5189 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  61 | time:  3.99s | CE 0.5278 |
#     | end of validation epoch  61 | time:  0.14s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  62 |    12/   51 batches | ms/batch 82.69 | CE 0.5691 |
# | epoch  62 |    24/   51 batches | ms/batch 78.03 | CE 0.4917 |
# | epoch  62 |    36/   51 batches | ms/batch 78.82 | CE 0.4298 |
# | epoch  62 |    48/   51 batches | ms/batch 78.79 | CE 0.3978 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  62 | time:  4.03s | CE 0.3801 |
#     | end of validation epoch  62 | time:  0.14s | Accuracy 0.8000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
#       Best validation model found and saved.
# ---------------------------------------------------------------------------------------------------
# | epoch  63 |    12/   51 batches | ms/batch 83.18 | CE 0.4040 |
# | epoch  63 |    24/   51 batches | ms/batch 81.43 | CE 0.3594 |
# | epoch  63 |    36/   51 batches | ms/batch 82.46 | CE 0.3450 |
# | epoch  63 |    48/   51 batches | ms/batch 83.55 | CE 0.4624 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  63 | time:  4.28s | CE 0.4530 |
#     | end of validation epoch  63 | time:  0.15s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  64 |    12/   51 batches | ms/batch 80.94 | CE 0.5469 |
# | epoch  64 |    24/   51 batches | ms/batch 81.56 | CE 0.4566 |
# | epoch  64 |    36/   51 batches | ms/batch 81.79 | CE 0.4886 |
# | epoch  64 |    48/   51 batches | ms/batch 81.90 | CE 0.4429 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  64 | time:  4.14s | CE 0.4311 |
#     | end of validation epoch  64 | time:  0.14s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  65 |    12/   51 batches | ms/batch 78.65 | CE 0.3094 |
# | epoch  65 |    24/   51 batches | ms/batch 81.53 | CE 0.3374 |
# | epoch  65 |    36/   51 batches | ms/batch 80.22 | CE 0.4000 |
# | epoch  65 |    48/   51 batches | ms/batch 80.06 | CE 0.3669 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  65 | time:  4.07s | CE 0.3910 |
#     | end of validation epoch  65 | time:  0.14s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  66 |    12/   51 batches | ms/batch 82.89 | CE 0.4086 |
# | epoch  66 |    24/   51 batches | ms/batch 82.45 | CE 0.3670 |
# | epoch  66 |    36/   51 batches | ms/batch 81.78 | CE 0.3807 |
# | epoch  66 |    48/   51 batches | ms/batch 84.54 | CE 0.3915 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  66 | time:  4.30s | CE 0.4013 |
#     | end of validation epoch  66 | time:  0.13s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  67 |    12/   51 batches | ms/batch 85.80 | CE 0.2235 |
# | epoch  67 |    24/   51 batches | ms/batch 87.65 | CE 0.3114 |
# | epoch  67 |    36/   51 batches | ms/batch 86.66 | CE 0.3355 |
# | epoch  67 |    48/   51 batches | ms/batch 85.79 | CE 0.3247 |
# ...
# | epoch  78 |    36/   51 batches | ms/batch 79.96 | CE 0.3076 |
# | epoch  78 |    48/   51 batches | ms/batch 82.39 | CE 0.3211 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  78 | time:  4.24s | CE 0.3124 |
#     | end of validation epoch  78 | time:  0.14s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  79 |    12/   51 batches | ms/batch 87.74 | CE 0.3047 |
# | epoch  79 |    24/   51 batches | ms/batch 84.75 | CE 0.4033 |
# | epoch  79 |    36/   51 batches | ms/batch 83.68 | CE 0.3580 |
# | epoch  79 |    48/   51 batches | ms/batch 82.70 | CE 0.3391 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  79 | time:  4.20s | CE 0.3591 |
#     | end of validation epoch  79 | time:  0.14s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  80 |    12/   51 batches | ms/batch 87.52 | CE 0.4091 |
# | epoch  80 |    24/   51 batches | ms/batch 85.95 | CE 0.4386 |
# | epoch  80 |    36/   51 batches | ms/batch 84.11 | CE 0.3818 |
# | epoch  80 |    48/   51 batches | ms/batch 82.54 | CE 0.3329 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  80 | time:  4.21s | CE 0.3390 |
#     | end of validation epoch  80 | time:  0.14s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  81 |    12/   51 batches | ms/batch 91.00 | CE 0.2760 |
# | epoch  81 |    24/   51 batches | ms/batch 85.65 | CE 0.2852 |
# | epoch  81 |    36/   51 batches | ms/batch 84.70 | CE 0.2846 |
# | epoch  81 |    48/   51 batches | ms/batch 82.52 | CE 0.2945 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  81 | time:  4.21s | CE 0.3056 |
#     | end of validation epoch  81 | time:  0.15s | Accuracy 0.6000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  82 |    12/   51 batches | ms/batch 79.20 | CE 0.8579 |
# | epoch  82 |    24/   51 batches | ms/batch 80.72 | CE 0.6853 |
# | epoch  82 |    36/   51 batches | ms/batch 79.60 | CE 0.5532 |
# | epoch  82 |    48/   51 batches | ms/batch 79.26 | CE 0.4935 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  82 | time:  4.05s | CE 0.4893 |
#     | end of validation epoch  82 | time:  0.13s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  83 |    12/   51 batches | ms/batch 81.54 | CE 0.3507 |
# | epoch  83 |    24/   51 batches | ms/batch 82.42 | CE 0.2633 |
# | epoch  83 |    36/   51 batches | ms/batch 83.52 | CE 0.2643 |
# | epoch  83 |    48/   51 batches | ms/batch 83.79 | CE 0.2909 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  83 | time:  4.29s | CE 0.2889 |
#     | end of validation epoch  83 | time:  0.13s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  84 |    12/   51 batches | ms/batch 78.99 | CE 0.2426 |
# | epoch  84 |    24/   51 batches | ms/batch 80.49 | CE 0.2415 |
# | epoch  84 |    36/   51 batches | ms/batch 80.91 | CE 0.2449 |
# | epoch  84 |    48/   51 batches | ms/batch 81.10 | CE 0.2487 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  84 | time:  4.13s | CE 0.2402 |
#     | end of validation epoch  84 | time:  0.14s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  85 |    12/   51 batches | ms/batch 84.68 | CE 0.3385 |
# | epoch  85 |    24/   51 batches | ms/batch 90.25 | CE 0.3153 |
# | epoch  85 |    36/   51 batches | ms/batch 92.98 | CE 0.2871 |
# | epoch  85 |    48/   51 batches | ms/batch 91.93 | CE 0.2802 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  85 | time:  4.66s | CE 0.2783 |
#     | end of validation epoch  85 | time:  0.14s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  86 |    12/   51 batches | ms/batch 83.47 | CE 0.1945 |
# | epoch  86 |    24/   51 batches | ms/batch 83.97 | CE 0.1868 |
# | epoch  86 |    36/   51 batches | ms/batch 86.74 | CE 0.2333 |
# | epoch  86 |    48/   51 batches | ms/batch 87.38 | CE 0.2181 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  86 | time:  4.44s | CE 0.2207 |
#     | end of validation epoch  86 | time:  0.14s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  87 |    12/   51 batches | ms/batch 83.51 | CE 0.2570 |
# | epoch  87 |    24/   51 batches | ms/batch 80.56 | CE 0.2147 |
# | epoch  87 |    36/   51 batches | ms/batch 83.61 | CE 0.1909 |
# | epoch  87 |    48/   51 batches | ms/batch 84.21 | CE 0.2006 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  87 | time:  4.30s | CE 0.1947 |
#     | end of validation epoch  87 | time:  0.14s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  88 |    12/   51 batches | ms/batch 83.20 | CE 0.2338 |
# | epoch  88 |    24/   51 batches | ms/batch 83.27 | CE 0.2622 |
# | epoch  88 |    36/   51 batches | ms/batch 82.08 | CE 0.2618 |
# | epoch  88 |    48/   51 batches | ms/batch 82.74 | CE 0.2789 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  88 | time:  4.21s | CE 0.2726 |
#     | end of validation epoch  88 | time:  0.14s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  89 |    12/   51 batches | ms/batch 79.52 | CE 0.2777 |
# | epoch  89 |    24/   51 batches | ms/batch 80.98 | CE 0.3085 |
# | epoch  89 |    36/   51 batches | ms/batch 81.21 | CE 0.2845 |
# | epoch  89 |    48/   51 batches | ms/batch 81.51 | CE 0.2493 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  89 | time:  4.14s | CE 0.2411 |
#     | end of validation epoch  89 | time:  0.13s | Accuracy 0.7667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  90 |    12/   51 batches | ms/batch 81.75 | CE 0.1099 |
# | epoch  90 |    24/   51 batches | ms/batch 82.19 | CE 0.1299 |
# | epoch  90 |    36/   51 batches | ms/batch 81.75 | CE 0.1479 |
# | epoch  90 |    48/   51 batches | ms/batch 83.80 | CE 0.1851 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  90 | time:  4.30s | CE 0.1785 |
#     | end of validation epoch  90 | time:  0.17s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  91 |    12/   51 batches | ms/batch 91.30 | CE 0.2178 |
# | epoch  91 |    24/   51 batches | ms/batch 88.79 | CE 0.1841 |
# | epoch  91 |    36/   51 batches | ms/batch 86.18 | CE 0.1619 |
# | epoch  91 |    48/   51 batches | ms/batch 84.87 | CE 0.1628 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  91 | time:  4.32s | CE 0.1581 |
#     | end of validation epoch  91 | time:  0.14s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  92 |    12/   51 batches | ms/batch 84.26 | CE 0.1795 |
# | epoch  92 |    24/   51 batches | ms/batch 84.18 | CE 0.1228 |
# | epoch  92 |    36/   51 batches | ms/batch 85.70 | CE 0.1227 |
# | epoch  92 |    48/   51 batches | ms/batch 86.24 | CE 0.1336 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  92 | time:  4.38s | CE 0.1375 |
#     | end of validation epoch  92 | time:  0.19s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
#       Best training model found.
# ---------------------------------------------------------------------------------------------------
# | epoch  93 |    12/   51 batches | ms/batch 83.31 | CE 0.4233 |
# | epoch  93 |    24/   51 batches | ms/batch 87.26 | CE 0.3531 |
# | epoch  93 |    36/   51 batches | ms/batch 85.10 | CE 0.3453 |
# | epoch  93 |    48/   51 batches | ms/batch 125.13 | CE 0.3861 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  93 | time:  6.77s | CE 0.3759 |
#     | end of validation epoch  93 | time:  0.34s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  94 |    12/   51 batches | ms/batch 266.26 | CE 0.2726 |
# | epoch  94 |    24/   51 batches | ms/batch 266.37 | CE 0.2948 |
# | epoch  94 |    36/   51 batches | ms/batch 259.93 | CE 0.2991 |
# | epoch  94 |    48/   51 batches | ms/batch 253.83 | CE 0.2622 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  94 | time: 12.99s | CE 0.2511 |
#     | end of validation epoch  94 | time:  0.37s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  95 |    12/   51 batches | ms/batch 250.63 | CE 0.1933 |
# | epoch  95 |    24/   51 batches | ms/batch 368.20 | CE 0.1978 |
# | epoch  95 |    36/   51 batches | ms/batch 321.41 | CE 0.2260 |
# | epoch  95 |    48/   51 batches | ms/batch 322.38 | CE 0.2637 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  95 | time: 16.18s | CE 0.2700 |
#     | end of validation epoch  95 | time:  0.40s | Accuracy 0.6333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  96 |    12/   51 batches | ms/batch 239.12 | CE 0.5701 |
# | epoch  96 |    24/   51 batches | ms/batch 241.40 | CE 0.4245 |
# | epoch  96 |    36/   51 batches | ms/batch 251.54 | CE 0.3583 |
# | epoch  96 |    48/   51 batches | ms/batch 258.03 | CE 0.3301 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  96 | time: 12.65s | CE 0.3177 |
#     | end of validation epoch  96 | time:  0.15s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  97 |    12/   51 batches | ms/batch 76.28 | CE 0.1632 |
# | epoch  97 |    24/   51 batches | ms/batch 78.99 | CE 0.1970 |
# | epoch  97 |    36/   51 batches | ms/batch 82.47 | CE 0.2163 |
# | epoch  97 |    48/   51 batches | ms/batch 81.70 | CE 0.2162 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  97 | time:  4.19s | CE 0.2046 |
#     | end of validation epoch  97 | time:  0.14s | Accuracy 0.6667 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  98 |    12/   51 batches | ms/batch 80.77 | CE 0.1476 |
# | epoch  98 |    24/   51 batches | ms/batch 85.70 | CE 0.1785 |
# | epoch  98 |    36/   51 batches | ms/batch 84.32 | CE 0.1805 |
# | epoch  98 |    48/   51 batches | ms/batch 84.69 | CE 0.1793 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  98 | time:  4.31s | CE 0.1705 |
#     | end of validation epoch  98 | time:  0.14s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch  99 |    12/   51 batches | ms/batch 80.17 | CE 0.2041 |
# | epoch  99 |    24/   51 batches | ms/batch 88.44 | CE 0.1550 |
# | epoch  99 |    36/   51 batches | ms/batch 84.26 | CE 0.1445 |
# | epoch  99 |    48/   51 batches | ms/batch 84.82 | CE 0.2768 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch  99 | time:  4.31s | CE 0.2784 |
#     | end of validation epoch  99 | time:  0.13s | Accuracy 0.7333 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# | epoch 100 |    12/   51 batches | ms/batch 98.45 | CE 0.5354 |
# | epoch 100 |    24/   51 batches | ms/batch 92.44 | CE 0.4201 |
# | epoch 100 |    36/   51 batches | ms/batch 139.38 | CE 0.3899 |
# | epoch 100 |    48/   51 batches | ms/batch 166.47 | CE 0.3610 |
# ---------------------------------------------------------------------------------------------------
#     | end of training epoch 100 | time:  8.73s | CE 0.3581 |
#     | end of validation epoch 100 | time:  0.38s | Accuracy 0.7000 |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------

# %%
# Load the best model's state dictionary
model.load_state_dict(torch.load('best_AlexNet.pt'))

# Set the model to evaluation mode
model.eval()

# Initialize variables for correctness and total test samples
correct = []
total = len(test_audio)

# Iterate over test data
for i in range(len(test_audio)):
    # Calculate STFT for the current audio sample
    this_spec = librosa.stft(test_audio[i].astype(np.float32), n_fft=512, hop_length=256)
    this_label = test_target[i]
    spec = torch.from_numpy(np.abs(this_spec))  # Use only the magnitude spectrogram
    this_label = torch.from_numpy(np.array(this_label)).long()

    # Forward pass through the model
    output = model(spec.unsqueeze(0).unsqueeze(1))

    # Calculate accuracy
    _, output_label = torch.max(output, 1)
    output_label = output_label.data.numpy()
    this_label = this_label.data.numpy()
    correct.append(np.sum(output_label == this_label))

# Calculate overall accuracy
overall_accuracy = np.sum(correct) / total * 100
print('Overall accuracy: {:.2f}%'.format(overall_accuracy))

# Calculate accuracy for each class
for i in range(len(test_audio) // 2):
    class_accuracy = np.sum(correct[i*2:i*2+2]) / 2 * 100
    print('Accuracy for {:s}: {:.2f}%'.format(all_event[i], class_accuracy))
# Out:
# Overall accuracy: 73.33%
# Accuracy for beach: 50.00%
# Accuracy for bus: 50.00%
# Accuracy for cafe/restaurant: 100.00%
# Accuracy for car: 100.00%
# Accuracy for city_center: 100.00%
# Accuracy for forest_path: 50.00%
# Accuracy for grocery_store: 100.00%
# Accuracy for home: 100.00%
# Accuracy for library: 50.00%
# Accuracy for metro_station: 100.00%
# Accuracy for office: 100.00%
# Accuracy for park: 100.00%
# Accuracy for residential_area: 0.00%
# Accuracy for train: 0.00%
# Accuracy for tram: 100.00%
